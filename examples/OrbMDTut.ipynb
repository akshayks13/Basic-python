# %% [markdown]
# <a href="https://colab.research.google.com/github/akshayks13/Basic-python/blob/main/examples/OrbMDTut.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# First you need to enable the gpu under Runtime, change runtime type. Then pip install the relevant libraries:

# %%
# !pip install -q orb-models
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 407.5/407.5 kB 21.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 152.8/152.8 kB 18.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 56.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 449.1/449.1 kB 40.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.6/140.6 kB 15.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 136.5/136.5 MB 6.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.7/14.7 MB 67.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 10.7 MB/s eta 0:00:00

# %% [markdown]
# Then we need to get the example input file and run script, which are in the github repo

# %%
# !wget https://raw.githubusercontent.com/orbital-materials/orb-models/main/examples/NaClWater.xyz
# !wget https://raw.githubusercontent.com/orbital-materials/orb-models/main/examples/NaClWaterMD.py
# Out:
# --2026-03-28 06:12:43--  https://raw.githubusercontent.com/orbital-materials/orb-models/main/examples/NaClWater.xyz
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 82391 (80K) [text/plain]
# Saving to: ‘NaClWater.xyz.1’
#
# NaClWater.xyz.1     100%[===================>]  80.46K  --.-KB/s    in 0.005s
#
# 2026-03-28 06:12:43 (15.0 MB/s) - ‘NaClWater.xyz.1’ saved [82391/82391]
#
# --2026-03-28 06:12:43--  https://raw.githubusercontent.com/orbital-materials/orb-models/main/examples/NaClWaterMD.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2724 (2.7K) [text/plain]
# Saving to: ‘NaClWaterMD.py.1’
#
# NaClWaterMD.py.1    100%[===================>]   2.66K  --.-KB/s    in 0s
#
# 2026-03-28 06:12:43 (60.7 MB/s) - ‘NaClWaterMD.py.1’ saved [2724/2724]

# %%
# !ls
# Out:
# NaClWaterMD.py	NaClWaterMD.py.1  NaClWater.xyz  NaClWater.xyz.1  sample_data

# %% [markdown]
# Then simply run the python script.

# %%
# !python NaClWaterMD.py
# Out:
# Using device: cuda
# /usr/local/lib/python3.12/dist-packages/orb_models/common/training/util.py:20: UserWarning: Setting global torch default dtype to torch.float32.
#   warnings.warn(f"Setting global torch default dtype to {torch_dtype}.")
# Downloading …onservative-omol-20250820.ckpt ━━━━━━━━━━━   0% 0:00:00 0.0/103.4
# Downloading …onservative-omol-20250820.ckpt ━━━━━━━━━━━   0% 0:00:00 0.0/103.4
# Downloading …onservative-omol-20250820.ckpt ━━━━━━━━━━━   0% 0:00:00 0.0/103.4
# Downloading …onservative-omol-20250820.ckpt ━━━━━━━━━━━   0% 0:00:00 0.0/103.4
# Downloading …onservative-omol-20250820.ckpt ━━━━━━━━━━━   0% 0:00:00 0.0/103.4
# Downloading …onservative-omol-20250820.ckpt ━━━━━━━━━━━   0% 0:00:00 0.0/103.4
# Downloading …onservative-omol-20250820.ckpt ━━━━━━━━━━━   0% 0:00:00 0.0/103.4
# Downloading …onservative-omol-20250820.ckpt ━━━━━━━━━━━   0% 0:00:00 0.0/103.4
# Downloading …onservative-omol-20250820.ckpt ━━━━━━━━━━━   0% 0:00:00 0.1/103.4
# Downloading …onservative-omol-20250820.ckpt ━━━━━━━━━━━   0% 0:00:00 0.1/103.4
# Downloading …onservative-omol-20250820.ckpt ━━━━━━━━━━━   0% 0:00:01 0.1/103.4
# Downloading …onservative-omol-20250820.ckpt ━━━━━━━━━━━   0% 0:00:01 0.3/103.4
# Downloading …onservative-omol-20250820.ckpt ━━━━━━━━━━━   1% 0:00:01 0.6/103.4
# Downloading …onservative-omol-20250820.ckpt ━━━━━━━━━━━   1% 0:00:01 0.6/103.4
# Downloading …onservative-omol-20250820.ckpt ━━━━━━━━━━━   1% 0:00:01 1.2/103.4
# Downloading …onservative-omol-20250820.ckpt ━━━━━━━━━━━   2% 0:00:01 1.6/103.4
# Downloading …onservative-omol-20250820.ckpt ━━━━━━━━━━━   2% 0:00:01 2.4/103.4
# Downloading …onservative-omol-20250820.ckpt ╸━━━━━━━━━━   5% 0:00:01 4.9/103.4
# Downloading …onservative-omol-20250820.ckpt ╸━━━━━━━━━━   5% 0:00:01 5.0/103.4
# Downloading …onservative-omol-20250820.ckpt ╸━━━━━━━━━━   7% 0:00:01 7.7/103.4
# Downloading …onservative-omol-20250820.ckpt ━╺━━━━━━━━━   9% 0:00:02 9.6/103.4
# Downloading …onservative-omol-20250820.ckpt ╸━━━━━━━━━  10% 0:00:02 10.0/103.4
# Downloading …onservative-omol-20250820.ckpt ━╺━━━━━━━━  12% 0:00:02 12.2/103.4
# Downloading …onservative-omol-20250820.ckpt ━╺━━━━━━━━  14% 0:00:02 14.4/103.4
# Downloading …onservative-omol-20250820.ckpt ━╺━━━━━━━━  14% 0:00:02 14.6/103.4
# Downloading …onservative-omol-20250820.ckpt ━╸━━━━━━━━  16% 0:00:02 17.0/103.4
# Downloading …onservative-omol-20250820.ckpt ━╸━━━━━━━━  18% 0:00:02 18.8/103.4
# Downloading …onservative-omol-20250820.ckpt ━╸━━━━━━━━  19% 0:00:02 19.3/103.4
# Downloading …onservative-omol-20250820.ckpt ━━╺━━━━━━━  21% 0:00:02 21.7/103.4
# Downloading …onservative-omol-20250820.ckpt ━━╺━━━━━━━  23% 0:00:02 23.4/103.4
# Downloading …onservative-omol-20250820.ckpt ━━╺━━━━━━━  23% 0:00:03 24.1/103.4
# Downloading …onservative-omol-20250820.ckpt ━━╸━━━━━━━  26% 0:00:03 26.5/103.4
# Downloading …onservative-omol-20250820.ckpt ━━╸━━━━━━━  27% 0:00:03 28.0/103.4
# Downloading …onservative-omol-20250820.ckpt ━━╸━━━━━━━  28% 0:00:03 29.0/103.4
# Downloading …onservative-omol-20250820.ckpt ━━━╺━━━━━━  30% 0:00:03 31.3/103.4
# Downloading …onservative-omol-20250820.ckpt ━━━╺━━━━━━  32% 0:00:03 32.8/103.4
# Downloading …onservative-omol-20250820.ckpt ━━━╺━━━━━━  33% 0:00:03 33.8/103.4
# Downloading …onservative-omol-20250820.ckpt ━━━╺━━━━━━  35% 0:00:03 36.2/103.4
# Downloading …onservative-omol-20250820.ckpt ━━━╸━━━━━━  36% 0:00:03 37.6/103.4
# Downloading …onservative-omol-20250820.ckpt ━━━╸━━━━━━  37% 0:00:03 38.7/103.4
# Downloading …onservative-omol-20250820.ckpt ━━━╸━━━━━━  40% 0:00:04 41.1/103.4
# Downloading …onservative-omol-20250820.ckpt ━━━━╺━━━━━  41% 0:00:04 42.4/103.4
# Downloading …onservative-omol-20250820.ckpt ━━━━╺━━━━━  42% 0:00:04 43.6/103.4
# Downloading …onservative-omol-20250820.ckpt ━━━━╺━━━━━  44% 0:00:04 46.0/103.4
# Downloading …onservative-omol-20250820.ckpt ━━━━╸━━━━━  46% 0:00:04 47.4/103.4
# Downloading …onservative-omol-20250820.ckpt ━━━━╸━━━━━  47% 0:00:04 48.6/103.4
# Downloading …onservative-omol-20250820.ckpt ━━━━╸━━━━━  49% 0:00:04 51.1/103.4
# Downloading …onservative-omol-20250820.ckpt ━━━━━╺━━━━  51% 0:00:04 52.4/103.4
# Downloading …onservative-omol-20250820.ckpt ━━━━━╺━━━━  52% 0:00:04 53.6/103.4
# Downloading …onservative-omol-20250820.ckpt ━━━━━╺━━━━  54% 0:00:04 56.1/103.4
# Downloading …onservative-omol-20250820.ckpt ━━━━━╸━━━━  55% 0:00:05 57.3/103.4
# Downloading …onservative-omol-20250820.ckpt ━━━━━╸━━━━  56% 0:00:05 58.4/103.4
# Downloading …onservative-omol-20250820.ckpt ━━━━━╸━━━━  59% 0:00:05 60.8/103.4
# Downloading …onservative-omol-20250820.ckpt ━━━━━━╺━━━  60% 0:00:05 62.3/103.4
# Downloading …onservative-omol-20250820.ckpt ━━━━━━╺━━━  61% 0:00:05 63.4/103.4
# Downloading …onservative-omol-20250820.ckpt ━━━━━━╺━━━  64% 0:00:05 65.9/103.4
# Downloading …onservative-omol-20250820.ckpt ━━━━━━╸━━━  65% 0:00:05 67.3/103.4
# Downloading …onservative-omol-20250820.ckpt ━━━━━━╸━━━  66% 0:00:05 68.5/103.4
# Downloading …onservative-omol-20250820.ckpt ━━━━━━╸━━━  69% 0:00:05 71.0/103.4
# Downloading …onservative-omol-20250820.ckpt ━━━━━━╸━━━  70% 0:00:06 72.3/103.4
# Downloading …onservative-omol-20250820.ckpt ━━━━━━━╺━━  71% 0:00:06 73.4/103.4
# Downloading …onservative-omol-20250820.ckpt ━━━━━━━╺━━  73% 0:00:06 76.0/103.4
# Downloading …onservative-omol-20250820.ckpt ━━━━━━━╺━━  75% 0:00:06 77.4/103.4
# Downloading …onservative-omol-20250820.ckpt ━━━━━━━╸━━  76% 0:00:06 78.5/103.4
# Downloading …onservative-omol-20250820.ckpt ━━━━━━━╸━━  78% 0:00:06 81.0/103.4
# Downloading …onservative-omol-20250820.ckpt ━━━━━━━╸━━  80% 0:00:06 82.4/103.4
# Downloading …onservative-omol-20250820.ckpt ━━━━━━━━╺━  81% 0:00:06 83.5/103.4
# Downloading …onservative-omol-20250820.ckpt ━━━━━━━━╺━  83% 0:00:06 86.1/103.4
# Downloading …onservative-omol-20250820.ckpt ━━━━━━━━╺━  84% 0:00:06 87.3/103.4
# Downloading …onservative-omol-20250820.ckpt ━━━━━━━━╸━  86% 0:00:07 88.6/103.4
# Downloading …onservative-omol-20250820.ckpt ━━━━━━━━╸━  88% 0:00:07 91.1/103.4
# Downloading …onservative-omol-20250820.ckpt ━━━━━━━━╸━  89% 0:00:07 92.0/103.4
# Downloading …onservative-omol-20250820.ckpt ━━━━━━━━━╺  91% 0:00:07 93.7/103.4
# Downloading …onservative-omol-20250820.ckpt ━━━━━━━━━╺  93% 0:00:07 96.2/103.4
# Downloading …onservative-omol-20250820.ckpt ━━━━━━━━━╺  93% 0:00:07 96.6/103.4
# Downloading …onservative-omol-20250820.ckpt ━━━━━━━━━╸  95% 0:00:07 98.7/103.4
# Downloading …onservative-omol-20250820.ckpt ━━━━━━━━━━╸  98% 0:00:07 101.0/103.4
# Downloading …onservative-omol-20250820.ckpt ━━━━━━━━━━╸  98% 0:00:07 101.8/103.4
# Downloading …onservative-omol-20250820.ckpt ━━━━━━━━━━━ 100% 0:00:07 103.4/103.4
#                                                                      MB
# /usr/local/lib/python3.12/dist-packages/ase/md/langevin.py:110: FutureWarning: The implementation of `fixcm=True` in `Langevin` does not strictly sample the correct NVT distributions. The deviations are typically small for large systems but can be more pronounced for small systems. Use `fixcm=False` together with `ase.constraints.FixCom`. `fixcm` is deprecated since ASE 3.28.0 and will be removed in a future release.
#   warnings.warn(msg, FutureWarning)
# W0328 06:14:35.702000 15484 torch/_inductor/utils.py:1679] [3/0] Not enough SMs to use max_autotune_gemm mode

# %% [markdown]
# It has generated 100 frames of simulation we can see it looks to be stable at 300 K

# %%
# !head md_nvt.log
# Out:
# Time[ps]      Etot[eV]     Epot[eV]     Ekin[eV]    T[K]
# 0.0000      -1471666.51  -1471726.88        60.37   294.8
# 0.0005      -1471666.52  -1471727.38        60.86   297.2
# 0.0010      -1471666.24  -1471728.62        62.38   304.7
# 0.0015      -1471666.37  -1471730.38        64.00   312.6
# 0.0020      -1471666.23  -1471731.88        65.65   320.6
# 0.0025      -1471665.97  -1471732.88        66.90   326.8
# 0.0030      -1471666.02  -1471733.00        66.98   327.1
# 0.0035      -1471665.93  -1471732.25        66.32   323.9
# 0.0040      -1471666.00  -1471731.12        65.12   318.1

# %% [markdown]
# The trajectory is stored in NaClWaterMD.xyz. We can visualise the a frame of the simulation:

# %%
pip install py3Dmol
# Out:
# Requirement already satisfied: py3Dmol in /usr/local/lib/python3.12/dist-packages (2.5.4)

# %%
import py3Dmol

# Function to extract a specific frame from the .xyz file
def extract_frame(xyz_file, frame_number):
    with open(xyz_file, "r") as f:
        lines = f.readlines()

    # Parse the file
    num_atoms = int(lines[0].strip())  # Number of atoms from the first line
    frame_start = frame_number * (num_atoms + 2)  # Start of the desired frame
    frame_lines = lines[frame_start : frame_start + num_atoms + 2]  # Extract frame
    return "".join(frame_lines)


# Specify the file and the frame number
frame_number = 3  # Pick the frame (0-based indexing)
xyz_file = "NaClWaterMD.xyz"
frame_data = extract_frame(xyz_file, frame_number)

# Visualize the extracted frame with balls and sticks
viewer = py3Dmol.view(width=800, height=400)
viewer.addModel(frame_data, "xyz")  # Add the trajectory frame
viewer.setStyle({
    "stick": {},                      # Default stick style
    "sphere": {"radius": 0.5}        # Sphere style with adjustable radius
})
viewer.zoomTo()
viewer.show()
# Out:
# <div id="3dmolviewer_17746789322417939"  style="position: relative; width: 800px; height: 400px;">
#         <p id="3dmolwarning_17746789322417939" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdn.jsdelivr.net/npm/3dmol@2.5.4/build/3Dmol-min.js');
# }
#
# var viewer_17746789322417939 = null;
# var warn = document.getElementById("3dmolwarning_17746789322417939");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_17746789322417939 = $3Dmol.createViewer(document.getElementById("3dmolviewer_17746789322417939"),{backgroundColor:"white"});
# viewer_17746789322417939.zoomTo();
# 	viewer_17746789322417939.addModel("1584\nLattice=\"25.25 0.0 0.0 0.0 25.25 0.0 0.0 0.0 25.25\" Properties=species:S:1:pos:R:3:momenta:R:3:forces:R:3 generated=T by=T VMD=T charge=0.0 spin=1.0 energy=-1471732.125 free_energy=-1471732.125 stress=\"0.0036182617768645287 -0.0006509115337394178 -0.0004920882056467235 -0.0006509115337394178 0.0031720013357698917 0.0011911980109289289 -0.0004920882056467235 0.0011911980109289289 0.002227988326922059\" pbc=\"T T T\"\nO        7.08042964       9.07166467      18.62473158       0.17012465       0.13497508      -0.56216744      -0.18139634      -1.41043210       0.15120333\nH        6.30904686       9.63883987      18.70050848      -0.19145191       0.05486094      -0.07748751      -0.01760289       1.06001401      -0.06341887\nH        6.72646158       8.23975277      18.98635178       0.21358638      -0.16512150      -0.02585618       0.32961500      -0.09789042      -0.27613327\nO        6.29054242      22.58631721      13.04080992       1.99571688      -1.20727507      -0.63811708       1.11068583       0.40389118      -2.07852411\nH        6.42415835      22.21850097      12.10767820      -0.01194987       0.07814349      -0.11703596      -0.64163899       0.66689301       1.77915859\nH        5.84284498      21.93895419      13.57241788      -0.26052127       0.17102975       0.06847576      -0.49674609      -0.67343456       0.32191783\nO        8.76405413       6.34674637      24.41436170       0.01369652       0.56477685       0.02569809       1.02822137      -0.65525305      -1.45105767\nH        8.44875369       6.71979154      25.24766745      -0.00835898      -0.08040688      -0.13586622      -0.14865914      -0.14902255       0.31634071\nH        9.42894481       5.60030775      24.52988028      -0.05512248      -0.21408553      -0.15447533      -0.97061098       0.64159358       0.81794453\nO        8.17033460      13.29389187       7.93204594       0.02356488       0.81664667      -0.52563550       0.30682775       1.08545840       0.52044320\nH        8.26781076      14.16250014       7.49321576      -0.04284000       0.05378093       0.02627876      -0.04856477      -0.28349790       0.19340144\nH        8.00129992      12.65180131       7.24247727       0.02563901       0.00014803      -0.12677729       0.23365313      -0.52397621      -0.99923992\nO       17.55856655       1.38765282       7.36859653      -0.08547078      -0.32475454      -0.39983175       0.49935329       1.37242281      -0.81949770\nH       17.91987372       2.19125655       6.86506794       0.26878074      -0.04932149       0.18605393      -0.55226111      -1.06183934       0.77762878\nH       18.00516654       1.40459876       8.24790181       0.25009985      -0.00468272       0.11673720       0.08619634       0.06669337       0.05397788\nO       21.90973277      22.18485604      20.96998801       0.50019512      -0.18969127       0.38660185       0.11377109      -0.44019401      -0.83813387\nH       21.28859450      21.84242850      20.19890556      -0.12655095      -0.20305362       0.29872130       0.75756049       1.24771798       1.49077654\nH       21.84574335      23.14488407      21.14781963      -0.11742129      -0.11493674      -0.14718450      -0.73479772      -0.45551097      -0.49770576\nO       19.98326241      24.04379575      -0.62399356       0.38911021      -0.34037672       0.30407057      -0.23167078       0.82273948       0.70928764\nH       19.09190857      23.66339873      -0.52513963      -0.10511579       0.21483430       0.04589632       0.05016024      -0.43440035       0.04606127\nH       20.04205536      24.63483872       0.18803718      -0.21414785      -0.13050694      -0.08859888       0.12283500      -0.27636033      -0.80522704\nO        2.09190623      18.99326423       4.81414939      -0.52481450       0.31798597      -0.26817851       2.36682677      -1.87786722      -2.38209367\nH        2.95686062      19.01950726       4.21235545      -0.08565559      -0.17 ...

# %% [markdown]
# Then you can run it long at a high temperatureat to see how stable it is. Or upload your own xyz file and run that just remember to update the cell size parameter and reduce the print frequency.

# %%
from NaClWaterMD import run_md_simulation

# Run with custom parameters
run_md_simulation(
    input_file="NaClWater.xyz",
    cell_size= 25.25,
    temperature_K=400,
    total_steps=100,
    traj_interval = 20,
    log_interval=20
)
# Out:
# Using device: cuda
# /usr/local/lib/python3.12/dist-packages/orb_models/common/training/util.py:20: UserWarning: Setting global torch default dtype to torch.float32.
#   warnings.warn(f"Setting global torch default dtype to {torch_dtype}.")
# /usr/local/lib/python3.12/dist-packages/ase/md/langevin.py:110: FutureWarning: The implementation of `fixcm=True` in `Langevin` does not strictly sample the correct NVT distributions. The deviations are typically small for large systems but can be more pronounced for small systems. Use `fixcm=False` together with `ase.constraints.FixCom`. `fixcm` is deprecated since ASE 3.28.0 and will be removed in a future release.
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# This script should also work on the gpu on a silicon Mac and is should be fast enough for many purposese. You probably want to load a conda environment or similar with
#
# ```
# conda create --name orb_env python=3.11
# conda activate orb_env
#
# ```
#
# Please reach out if you have any questions or issues. My email is tim@orbitalmaterials.com
# Happy simulating!

# %%
# !cat dft.py
# Out:
# cat: dft.py: No such file or directory

# %%
# !python dft.py
# Out:
# /usr/local/lib/python3.12/dist-packages/orb_models/common/training/util.py:20: UserWarning: Setting global torch default dtype to torch.float32.
#   warnings.warn(f"Setting global torch default dtype to {torch_dtype}.")
# W0327 17:44:56.838000 27127 torch/_inductor/utils.py:1679] [0/0_1] Not enough SMs to use max_autotune_gemm mode
#       Step     Time          Energy          fmax
# BFGS:    0 17:45:19      -57.375542       46.874512
# BFGS:    1 17:45:19      -68.051117        9.801895
# BFGS:    2 17:45:19      -70.728523        6.038763
# BFGS:    3 17:45:19      -72.830284        2.759923
# BFGS:    4 17:45:19      -73.747513        1.281506
# BFGS:    5 17:45:19      -74.255287        0.885246
# BFGS:    6 17:45:19      -74.588699        0.893054
# BFGS:    7 17:45:19      -74.875473        0.862470
# BFGS:    8 17:45:19      -75.099792        0.955433
# BFGS:    9 17:45:19      -75.391006        1.046964
# BFGS:   10 17:45:19      -76.164909        1.289119
# BFGS:   11 17:45:19      -76.798325        1.874583
# BFGS:   12 17:45:20      -77.062584        1.127211
# BFGS:   13 17:45:20      -77.198654        1.028308
# BFGS:   14 17:45:20      -77.920509        0.975520
# BFGS:   15 17:45:20      -78.146759        1.284797
# BFGS:   16 17:45:20      -78.315918        1.121938
# BFGS:   17 17:45:20      -78.628914        0.879950
# BFGS:   18 17:45:20      -78.865761        0.988684
# BFGS:   19 17:45:20      -79.111320        1.073998
# BFGS:   20 17:45:20      -79.277016        0.847091
# BFGS:   21 17:45:20      -79.418724        0.766724
# BFGS:   22 17:45:20      -79.580002        0.679207
# BFGS:   23 17:45:20      -79.744690        0.561645
# BFGS:   24 17:45:20      -79.835411        0.574090
# BFGS:   25 17:45:20      -79.870834        0.564219
# BFGS:   26 17:45:20      -80.064499        0.563561
# BFGS:   27 17:45:20      -80.146683        0.564213
# BFGS:   28 17:45:20      -80.209084        0.493571
# BFGS:   29 17:45:20      -80.255554        0.529441
# BFGS:   30 17:45:20      -80.363892        0.588617
# BFGS:   31 17:45:20      -80.473480        0.580259
# BFGS:   32 17:45:20      -80.580811        0.622890
# BFGS:   33 17:45:20      -80.671333        0.675274
# BFGS:   34 17:45:20      -80.757370        0.682261
# BFGS:   35 17:45:20      -80.863457        0.617007
# BFGS:   36 17:45:20      -81.011734        0.684645
# BFGS:   37 17:45:20      -81.135567        0.719356
# BFGS:   38 17:45:20      -81.239777        0.807580
# BFGS:   39 17:45:20      -81.357872        0.698192
# BFGS:   40 17:45:20      -81.518066        0.790953
# BFGS:   41 17:45:21      -81.741982        0.724690
# BFGS:   42 17:45:21      -81.890831        0.610910
# BFGS:   43 17:45:21      -81.977394        0.635307
# BFGS:   44 17:45:21      -82.033173        0.516653
# BFGS:   45 17:45:21      -82.159790        0.439975
# BFGS:   46 17:45:21      -82.280235        0.539379
# BFGS:   47 17:45:21      -82.347168        0.586577
# BFGS:   48 17:45:21      -82.399521        0.606422
# BFGS:   49 17:45:21      -82.478233        0.518185
# BFGS:   50 17:45:21      -82.560822        0.380265
# BFGS:   51 17:45:21      -82.615250        0.367169
# BFGS:   52 17:45:21      -82.655579        0.380244
# BFGS:   53 17:45:21      -82.685944        0.386619
# BFGS:   54 17:45:21      -82.730858        0.343280
# BFGS:   55 17:45:21      -82.828911        0.409816
# BFGS:   56 17:45:21      -82.907379        0.573413
# BFGS:   57 17:45:21      -82.959801        0.572468
# BFGS:   58 17:45:21      -83.014404        0.503405
